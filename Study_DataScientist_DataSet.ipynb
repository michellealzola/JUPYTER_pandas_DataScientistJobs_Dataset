# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
# Some intermediate-level real-world problems and solutions that can be
# addressed using numpy, pandas, and matplotlib
# with this dataset: https://www.kaggle.com/datasets/andrewmvd/data-scientist-jobs

# %%
# Loading and Getting Information

# %%
df = pd.read_csv('DataScientist.csv', index_col='Job Title')

# %%
df
# Out:
#                                                     Unnamed: 0  index  \
# Job Title
# Senior Data Scientist                                        0      0
# Data Scientist, Product Analytics                            1      1
# Data Science Manager                                         2      2
# Data Analyst                                                 3      3
# Director, Data Science                                       4      4
# ...                                                        ...    ...
# AWS Data Engineer                                         3904   4375
# Data Analyst â Junior                                     3905   4376
# Security Analytics Data Engineer                          3906   4377
# Security Analytics Data Engineer                          3907   4378
# Patient Safety Physician or Safety Scientist - ...        3908   4379
#
#                                                                  Salary Estimate  \
# Job Title
# ...

# %%
df_data = df.drop(['Unnamed: 0', 'index'], axis=1)

# %%
df_data
# Out:
#                                                                  Salary Estimate  \
# Job Title
# Senior Data Scientist                               $111K-$181K (Glassdoor est.)
# Data Scientist, Product Analytics                   $111K-$181K (Glassdoor est.)
# Data Science Manager                                $111K-$181K (Glassdoor est.)
# Data Analyst                                        $111K-$181K (Glassdoor est.)
# Director, Data Science                              $111K-$181K (Glassdoor est.)
# ...                                                                          ...
# AWS Data Engineer                                    $55K-$112K (Glassdoor est.)
# Data Analyst â Junior                                $55K-$112K (Glassdoor est.)
# Security Analytics Data Engineer                     $55K-$112K (Glassdoor est.)
# Security Analytics Data Engineer                     $55K-$112K (Glassdoor est.)
# ...

# %%
# Problem 1: Which top 15 companies are hiring the most data scientists?

# %%
top_companies_hiring_ds = df_data['Company Name'].value_counts().nlargest(15)

# %%
top_companies_hiring_ds
# Out:
# Apple\n4.1                               60
# IBM\n3.7                                 57
# Amazon\n3.9                              47
# Staffigo Technical Services, LLC\n5.0    28
# Facebook\n4.5                            25
# Diverse Lynx\n3.9                        25
# Solekai Systems Corp\n4.2                24
# Southwest Research Institute\n4.1        23
# Varsity Tutors\n4.2                      21
# Humana\n3.6                              20
# GSK\n3.9                                 18
# CyberCoders\n4.2                         18
# J&J Family of Companies\n4.0             17
# Houston Methodist\n4.1                   16
# Pfizer\n4.1                              16
# Name: Company Name, dtype: int64

# %%
top_companies_hiring_ds.plot(kind='bar')
plt.title('Top 15 Companies that are hiring Data Scientists')
plt.xlabel('Company')
plt.ylabel('Job Postings')
plt.show()

# %%
# Problem 2: What are the top 5 most common job titles for data scientists?

# %%
df_most_common_jobtitles = df_data.index.value_counts().nlargest(5)

# %%
df_most_common_jobtitles
# Out:
# Data Scientist           274
# Data Engineer            260
# Data Analyst             246
# Senior Data Scientist     91
# Senior Data Analyst       47
# Name: Job Title, dtype: int64

# %%
df_most_common_jobtitles.plot(kind='bar')
plt.show()

# %%
# Problem 3: What is the average salary for data scientists per sector?

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3909 entries, Senior Data Scientist to Patient Safety Physician or Safety Scientist - UK, Europe or the US
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Salary Estimate    3909 non-null   object
#  1   Job Description    3909 non-null   object
#  2   Rating             3909 non-null   float64
#  3   Company Name       3909 non-null   object
#  4   Location           3909 non-null   object
#  5   Headquarters       3909 non-null   object
#  6   Size               3909 non-null   object
#  7   Founded            3909 non-null   int64
#  8   Type of ownership  3909 non-null   object
#  9   Industry           3909 non-null   object
#  10  Sector             3909 non-null   object
#  11  Revenue            3909 non-null   object
#  12  Competitors        3909 non-null   object
#  13  Easy Apply         3909 non-null   object
# ...

# %%
df_data['Salary Estimate'] = df_data['Salary Estimate'].apply(lambda x: x.split('(Glassdoor est.)'))

# %%
df_data['Salary Estimate']
# Out:
# Job Title
# Senior Data Scientist                                                  [$111K-$181K , ]
# Data Scientist, Product Analytics                                      [$111K-$181K , ]
# Data Science Manager                                                   [$111K-$181K , ]
# Data Analyst                                                           [$111K-$181K , ]
# Director, Data Science                                                 [$111K-$181K , ]
#                                                                              ...
# AWS Data Engineer                                                       [$55K-$112K , ]
# Data Analyst â Junior                                                   [$55K-$112K , ]
# Security Analytics Data Engineer                                        [$55K-$112K , ]
# Security Analytics Data Engineer                                        [$55K-$112K , ]
# Patient Safety Physician or Safety Scientist - UK, Europe or the US     [$55K-$112K , ]
# ...

# %%
df_data['Salary Estimate'] = df_data['Salary Estimate'].apply(lambda  x: x[0])

# %%
df_data['Salary Estimate']
# Out:
# Job Title
# Senior Data Scientist                                                  $111K-$181K
# Data Scientist, Product Analytics                                      $111K-$181K
# Data Science Manager                                                   $111K-$181K
# Data Analyst                                                           $111K-$181K
# Director, Data Science                                                 $111K-$181K
#                                                                            ...
# AWS Data Engineer                                                       $55K-$112K
# Data Analyst â Junior                                                   $55K-$112K
# Security Analytics Data Engineer                                        $55K-$112K
# Security Analytics Data Engineer                                        $55K-$112K
# Patient Safety Physician or Safety Scientist - UK, Europe or the US     $55K-$112K
# Name: Salary Estimate, Length: 3909, dtype: object

# %%
v1 = []
for values in df_data['Salary Estimate']:
    v1.append(values.replace('K', '000'))

# %%
v1
# Out:
# ['$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$111000-$181000 ',
#  '$120000-$140000 ',
#  '$120000-$140000 ',
#  '$120000-$140000 ',
#  '$120000-$140000 ',
#  '$120000-$140000 ',
#  '$120000-$140000 ',
#  '$120000-$140000 ',
#  '$120000-$140000 ',
#  '$120000-$140000 ',
#  '$120000-$140000 ',
#  '$120000-$140000 ',
#  '$120000-$140000 ',
#  '$120000-$140000 ',
# ...

# %%
v2 = []
for values in v1:
    v2.append(values.replace('$', ''))

# %%
v2
# Out:
# ['111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '111000-181000 ',
#  '120000-140000 ',
#  '120000-140000 ',
#  '120000-140000 ',
#  '120000-140000 ',
#  '120000-140000 ',
#  '120000-140000 ',
#  '120000-140000 ',
#  '120000-140000 ',
#  '120000-140000 ',
#  '120000-140000 ',
#  '120000-140000 ',
#  '120000-140000 ',
#  '120000-140000 ',
#  '120000-140000 ',
#  '120000-140000 ',
#  '120000-140000 ',
#  '120000-140000 ',
# ...

# %%
v3 = []
for values in v2:
    v3.append(values.split('-'))

# %%
v3
# Out:
# [['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['111000', '181000 '],
#  ['120000', '140000 '],
#  ['120000', '140000 '],
#  ['120000', '140000 '],
#  ['120000', '140000 '],
#  ['120000', '140000 '],
#  ['120000', '140000 '],
#  ['120000', '140000 '],
#  ['120000', '140000 '],
# ...

# %%
v4 = []
for values in v3:
    int1 = int(values[0].replace('34','70720').replace('10','20800').replace('17','35360'))
    int2 = int(values[1].replace('53 Per Hour', '110240').replace('26 Per Hour', '54080').replace('27 Per Hour', '56160').replace('(Employer est.)',''))
    v4.append((int1 + int2) / 2)

# %%
v4
# Out:
# [56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  56130500.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
#  133000.0,
# ...

# %%
df_data['Salary Estimate'] = v4

# %%
df_data
# Out:
#                                                     Salary Estimate  \
# Job Title
# Senior Data Scientist                                    56130500.0
# Data Scientist, Product Analytics                        56130500.0
# Data Science Manager                                     56130500.0
# Data Analyst                                             56130500.0
# Director, Data Science                                   56130500.0
# ...                                                             ...
# AWS Data Engineer                                           83500.0
# Data Analyst â Junior                                       83500.0
# Security Analytics Data Engineer                            83500.0
# Security Analytics Data Engineer                            83500.0
# Patient Safety Physician or Safety Scientist - ...          83500.0
#
#                                                                                       Job Description  \
# Job Title
# ...

# %%
df_sector_average_salary = df_data.groupby('Sector')['Salary Estimate'].mean()

# %%
df_sector_average_salary
# Out:
# Sector
# -1                                    1.950007e+09
# Accounting & Legal                    4.587401e+06
# Aerospace & Defense                   9.566100e+09
# Agriculture & Forestry                7.175200e+06
# Arts, Entertainment & Recreation      1.768014e+10
# Biotech & Pharmaceuticals             1.815725e+09
# Business Services                     2.352023e+09
# Construction, Repair & Maintenance    1.105014e+10
# Consumer Services                     8.855527e+09
# Education                             3.510086e+09
# Finance                               2.630973e+09
# Government                            4.321424e+09
# Health Care                           9.038134e+08
# Information Technology                2.057433e+09
# Insurance                             3.253872e+09
# Manufacturing                         4.071396e+09
# Media                                 7.091600e+09
# Mining & Metals                       3.609850e+07
# ...

# %%
df_sector_average_salary.plot(kind='bar')
plt.title('Average Salary per Sector')
plt.show()

# %%
# Problem 4: How many data scientist jobs require specific skills?

# %%
skills = {'Python': 0,
          'R': 0,
          'SQL': 0,
          'Excel': 0,
          'Machine Learning': 0,
          'Deep Learning': 0,
          'NLP': 0,
          'Tableau': 0
}

# %%
for index, row in df_data.iterrows():
    for skill in skills.keys():
        if skill in row['Job Description']:
            skills[skill] += 1

# %%
print(skills.keys(), skills.values())
# Out:
# dict_keys(['Python', 'R', 'SQL', 'Excel', 'Machine Learning', 'Deep Learning', 'NLP', 'Tableau']) dict_values([2003, 3706, 2014, 1477, 491, 91, 190, 669])

# %%
plt.bar(skills.keys(), skills.values())
plt.xticks(rotation=90)
plt.title('Specific Skills required for a Data Scientist Job based on Job Postings')
plt.xlabel('Job Postings')
plt.show()
